# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
root_dir = Path(r"D:\second_extraction")
tracy_dir = root_dir / "Tracy_6230"
idx_tracy = pd.read_csv(tracy_dir / "features_index.csv")

print("Number of feature files for Tracy_6230:", len(idx_tracy))
print("Unique shapes:", idx_tracy['shape'].nunique())
# Out:
# Number of feature files for Tracy_6230: 7816
# Unique shapes: 3

# %%
row = idx_tracy.iloc[0]
fname = tracy_dir / (Path(row["feature_path"]).stem + ".npz")
f = np.load(fname)
for key in f.keys():
    print(f"{key}: {f[key].shape}")
# Out:
# feature: (1, 128, 33125)
# sr: ()
# source_path: ()
