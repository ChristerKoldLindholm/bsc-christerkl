# %%
import numpy as np
from pathlib import Path
import torch

base_dir = r"E:\autoencoder_outputs_7750"

# %%
data_keys = []
with np.load(Path(base_dir) / "model_results.npz") as data:
    # Check keys.
    for key in data.keys():
        data_keys.append(key)
data_keys
# Out:
# ['n_files',
#  'train_files',
#  'n_train_files',
#  'val_files',
#  'n_val_files',
#  'test_files',
#  'n_test_files',
#  'segment_frames',
#  'T_target',
#  'mels_start',
#  'mels_end',
#  'lat_dim',
#  'hid_dim',
#  'lr',
#  'batch_size',
#  'patience',
#  'scaler_scale',
#  'scaler_mean',
#  'scaler_var']

# %%
with np.load(Path(base_dir) / "model_results.npz") as data:
    train_files = data["train_files"]
    val_files = data["val_files"]
    test_files = data["test_files"]

with np.load(Path(base_dir) / "train_stats.npz") as d:
    n_epochs = d["n_epochs"]
    train_losses = d["train_losses"]
    val_losses = d["val_losses"]

# %%
train_losses
# Out:
# array([0.29081199, 0.17020799])
